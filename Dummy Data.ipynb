# %% [markdown]
# # Question 1:
# Create random numbers

# %%
import numpy as np
#data0
np.random.seed(0)
mean = (-3, 0)
cov = [[1.0,0.8],[0.8,1.0]]
data0 = np.random.multivariate_normal(mean,cov,size=(500)).reshape(500,2)
data0
# Out:
# array([[-4.80006782e+00, -1.54698618e+00],
#        [-4.63714503e+00, -2.19879728e-01],
#        [-4.46267867e+00, -2.08076347e+00],
#        [-3.85346966e+00, -9.49196365e-01],
#        [-3.03192065e+00,  2.27764648e-01],
#        [-3.59653339e+00,  3.23229932e-01],
#        [-3.76046080e+00, -6.83506760e-01],
#        [-3.52660272e+00, -3.15568548e-01],
#        [-4.35253112e+00, -1.48228460e+00],
#        [-3.02691331e+00, -5.67090887e-01],
#        [-7.84713550e-01,  2.62867115e+00],
#        [-3.58538300e+00, -1.05476937e+00],
#        [-4.69336749e+00, -2.61318911e+00],
#        [-2.98421761e+00, -1.02603072e-01],
#        [-4.91877408e+00, -9.89469999e-01],
#        [-3.26658152e+00, -2.74105461e-02],
#        [-1.53138965e+00,  2.15844669e-01],
#        [-2.71938344e+00,  3.79500330e-01],
#        [-4.54738211e+00, -7.86930327e-01],
#        [-2.53695299e+00,  2.71853959e-01],
#        [-1.55620621e+00,  5.45695585e-01],
#        [-1.99817931e+00,  2.23559938e+00],
# ...

# %%
x = data[:,0]
y = data[:,1]

# %% [markdown]
# # Problem 2:
# Visualization with a scatter plot

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
fig, ax = plt.subplots()
plt.scatter(x,y)
plt.title('Scatter')
plt.xlabel('Data 1')
plt.ylabel('Data 2')
plt.show()

# %% [markdown]
# # Problem 3:
# Visualization with a Histogram

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
fig, ax = plt.subplots()
plt.hist(x,bins=60)
plt.title('Histogram')
plt.xlabel('x1')
plt.ylabel('Frequency')
plt.show()

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
fig, ax = plt.subplots()
plt.hist(y,bins=60)
plt.title('Histogram')
plt.xlabel('x2')
plt.ylabel('Frequency')
plt.show()

# %%
#using xlim to set the range of x-axis
import matplotlib.pyplot as plt
# %matplotlib inline
fig, ax = plt.subplots()
plt.hist(x,bins=60)
plt.xlim([-5,2])
plt.title('Histogram')
plt.xlabel('x1')
plt.ylabel('Frequency')
plt.show()

# %%
#using xlim to set the range of x-axis
import matplotlib.pyplot as plt
# %matplotlib inline
fig, ax = plt.subplots()
plt.hist(y,bins=60)
plt.xlim([-5,2])
plt.title('Histogram')
plt.xlabel('x2')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# # Question 4:
# Adding Data

# %%
#Data1
np.random.seed(0)
mean = (0, -3)
cov = [[1.0,0.8],[0.8,1.0]]
data1 = np.random.multivariate_normal(mean,cov,size=(500)).reshape(500,2)
data
# Out:
# array([[-4.80006782e+00, -1.54698618e+00],
#        [-4.63714503e+00, -2.19879728e-01],
#        [-4.46267867e+00, -2.08076347e+00],
#        [-3.85346966e+00, -9.49196365e-01],
#        [-3.03192065e+00,  2.27764648e-01],
#        [-3.59653339e+00,  3.23229932e-01],
#        [-3.76046080e+00, -6.83506760e-01],
#        [-3.52660272e+00, -3.15568548e-01],
#        [-4.35253112e+00, -1.48228460e+00],
#        [-3.02691331e+00, -5.67090887e-01],
#        [-7.84713550e-01,  2.62867115e+00],
#        [-3.58538300e+00, -1.05476937e+00],
#        [-4.69336749e+00, -2.61318911e+00],
#        [-2.98421761e+00, -1.02603072e-01],
#        [-4.91877408e+00, -9.89469999e-01],
#        [-3.26658152e+00, -2.74105461e-02],
#        [-1.53138965e+00,  2.15844669e-01],
#        [-2.71938344e+00,  3.79500330e-01],
#        [-4.54738211e+00, -7.86930327e-01],
#        [-2.53695299e+00,  2.71853959e-01],
#        [-1.55620621e+00,  5.45695585e-01],
#        [-1.99817931e+00,  2.23559938e+00],
# ...

# %%
x1 = data1[:,0]
y1 = data1[:,1]

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
fig, ax = plt.subplots()
plt.scatter(x,y,label='data0')
plt.scatter(x1,y1,label='data1')
plt.title('Scatter')
plt.xlabel('x1')
plt.ylabel('x2')
plt.legend()
plt.show()

# %% [markdown]
# # Problem 5:
# Combining Data

# %%
np.concatenate((data0,data1),axis=0)
# Out:
# array([[-4.80006782, -1.54698618],
#        [-4.63714503, -0.21987973],
#        [-4.46267867, -2.08076347],
#        ...,
#        [-0.40484501, -3.14372258],
#        [ 0.1584315 , -2.78199606],
#        [ 1.20196495, -2.02452628]])

# %%
print(np.concatenate((data0,data1),axis=0).shape)
# Out:
# (1000, 2)

# %%
np.vstack((data0,data1))
# Out:
# array([[-4.80006782, -1.54698618],
#        [-4.63714503, -0.21987973],
#        [-4.46267867, -2.08076347],
#        ...,
#        [-0.40484501, -3.14372258],
#        [ 0.1584315 , -2.78199606],
#        [ 1.20196495, -2.02452628]])

# %%
print(np.vstack((data0,data1)).shape)
# Out:
# (1000, 2)

# %% [markdown]
# # Question 6:
# Labeling

# %%
# 0s labels for data created in question 1(data0)
label_data0= np.zeros((500,1))
labeled_data0 = np.concatenate((data0, label_data0), axis = 1)
labeled_data0
# Out:
# array([[-4.80006782, -1.54698618,  0.        ],
#        [-4.63714503, -0.21987973,  0.        ],
#        [-4.46267867, -2.08076347,  0.        ],
#        ...,
#        [-3.40484501, -0.14372258,  0.        ],
#        [-2.8415685 ,  0.21800394,  0.        ],
#        [-1.79803505,  0.97547372,  0.        ]])

# %%
# 1s labels for data created in question 4(data1)
label_data1= np.ones((500,1))
labeled_data1 = np.concatenate((data1, label_data1), axis = 1)
labeled_data1
# Out:
# array([[-1.80006782, -4.54698618,  1.        ],
#        [-1.63714503, -3.21987973,  1.        ],
#        [-1.46267867, -5.08076347,  1.        ],
#        ...,
#        [-0.40484501, -3.14372258,  1.        ],
#        [ 0.1584315 , -2.78199606,  1.        ],
#        [ 1.20196495, -2.02452628,  1.        ]])

# %%
#combine the labeled data 
np.concatenate((labeled_data0,labeled_data1),axis=0)
# Out:
# array([[-4.80006782, -1.54698618,  0.        ],
#        [-4.63714503, -0.21987973,  0.        ],
#        [-4.46267867, -2.08076347,  0.        ],
#        ...,
#        [-0.40484501, -3.14372258,  1.        ],
#        [ 0.1584315 , -2.78199606,  1.        ],
#        [ 1.20196495, -2.02452628,  1.        ]])

# %%
print(np.concatenate((labeled_data0,labeled_data1),axis=0).shape)
# Out:
# (1000, 3)
